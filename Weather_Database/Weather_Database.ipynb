# %%
import sys
sys.path.append("C:/Users/Kompyuter/anaconda3/envs/PythonData/lib/site-packages")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import timeit

# %%
from citipy import citipy
from datetime import datetime

# %%
from config import weather_api_key

# %%
#create a set of randome lats and longs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | sibolga
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 1 | colares
# Processing Record 8 of Set 1 | kirakira
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | mount isa
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | ixtapa
# Processing Record 21 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | ironton
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | monte patria
# Processing Record 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | frumusita
# Processing Record 41 of Set 1 | saint-pierre
# Processing Record 42 of Set 1 | chabahar
# Processing Record 43 of Set 1 | ponnani
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | mae sai
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | wajima
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | bixby
# Processing Record 4 of Set 2 | high rock
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | gizo
# Processing Record 12 of Set 2 | manggar
# Processing Record 13 of Set 2 | aksarka
# Processing Record 14 of Set 2 | anadyr
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | victor harbor
# Processing Record 19 of Set 2 | sao joao da barra
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | marawi
# Processing Record 22 of Set 2 | port lincoln
# Processing Record 23 of Set 2 | mazagao
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | la palma
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | mackay
# Processing Record 29 of Set 2 | yishui
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | kijang
# Processing Record 33 of Set 2 | kieta
# Processing Record 34 of Set 2 | pangobilian
# Processing Record 35 of Set 2 | tual
# Processing Record 36 of Set 2 | mersing
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 2 | abha
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | siilinjarvi
# Processing Record 45 of Set 2 | guerrero negro
# Processing Record 46 of Set 2 | huaidian
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | caibarien
# Processing Record 49 of Set 2 | quatre cocos
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | nautla
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | obo
# Processing Record 4 of Set 3 | elizabeth city
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | las vegas
# Processing Record 7 of Set 3 | kaeo
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | umm lajj
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | smolenka
# Processing Record 12 of Set 3 | husavik
# Processing Record 13 of Set 3 | wanning
# Processing Record 14 of Set 3 | satipo
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | mehndawal
# Processing Record 18 of Set 3 | muravlenko
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | biak
# Processing Record 22 of Set 3 | pouebo
# Processing Record 23 of Set 3 | la rioja
# Processing Record 24 of Set 3 | tuyen quang
# Processing Record 25 of Set 3 | zhangjiakou
# Processing Record 26 of Set 3 | tateyama
# Processing Record 27 of Set 3 | larap
# Processing Record 28 of Set 3 | pathein
# Processing Record 29 of Set 3 | beringovskiy
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | wonthaggi
# Processing Record 32 of Set 3 | bayan
# Processing Record 33 of Set 3 | lufilufi
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | lamu
# Processing Record 36 of Set 3 | port hawkesbury
# Processing Record 37 of Set 3 | san isidro
# Processing Record 38 of Set 3 | nyagan
# Processing Record 39 of Set 3 | krutikha
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | encruzilhada do sul
# Processing Record 42 of Set 3 | kampene
# Processing Record 43 of Set 3 | herat
# Processing Record 44 of Set 3 | verkhnyaya inta
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | celestun
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | verkhnetulomskiy
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | buzmeyin
# Processing Record 2 of Set 4 | laranjeiras do sul
# Processing Record 3 of Set 4 | yanliang
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | otautau
# Processing Record 6 of Set 4 | clyde river
# Processing Record 7 of Set 4 | port hedland
# Processing Record 8 of Set 4 | fairbanks
# Processing Record 9 of Set 4 | kenitra
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | tabou
# Processing Record 12 of Set 4 | calama
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | lipin bor
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | siderno
# Processing Record 18 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 4 | coihaique
# Processing Record 20 of Set 4 | senneterre
# Processing Record 21 of Set 4 | angoche
# Processing Record 22 of Set 4 | gillette
# Processing Record 23 of Set 4 | karlstad
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | sangar
# Processing Record 26 of Set 4 | hovd
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | haines junction
# Processing Record 30 of Set 4 | hirara
# Processing Record 31 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 4 | ketchikan
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | rio verde de mato grosso
# Processing Record 35 of Set 4 | gogrial
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | santa cruz de tenerife
# Processing Record 38 of Set 4 | mwense
# Processing Record 39 of Set 4 | biograd na moru
# Processing Record 40 of Set 4 | wuwei
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | aleppo
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | moindou
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | kavaratti
# Processing Record 48 of Set 4 | bongaree
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | adeje
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | encantado
# Processing Record 4 of Set 5 | buraydah
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | broken hill
# Processing Record 7 of Set 5 | tuktoyaktuk
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | necochea
# Processing Record 10 of Set 5 | comodoro rivadavia
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | yomou
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | palmerston
# Processing Record 15 of Set 5 | namibe
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | miramar
# Processing Record 18 of Set 5 | faya
# Processing Record 19 of Set 5 | dingle
# Processing Record 20 of Set 5 | opuwo
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | orshanka
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | skjervoy
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | hailar
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | guna
# Processing Record 31 of Set 5 | san quintin
# Processing Record 32 of Set 5 | kyabe
# Processing Record 33 of Set 5 | wexford
# Processing Record 34 of Set 5 | jamestown
# Processing Record 35 of Set 5 | ciudad bolivar
# Processing Record 36 of Set 5 | jatiroto
# Processing Record 37 of Set 5 | seymchan
# Processing Record 38 of Set 5 | taoudenni
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | wageningen
# Processing Record 41 of Set 5 | asau
# Processing Record 42 of Set 5 | mananara
# Processing Record 43 of Set 5 | kutum
# Processing Record 44 of Set 5 | aktau
# Processing Record 45 of Set 5 | brandenburg
# Processing Record 46 of Set 5 | militello in val di catania
# Processing Record 47 of Set 5 | golakganj
# Processing Record 48 of Set 5 | pergamino
# Processing Record 49 of Set 5 | mikhaylovka
# Processing Record 50 of Set 5 | vanavara
# Processing Record 1 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 6 | prescot
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | black forest
# Processing Record 5 of Set 6 | aginskoye
# Processing Record 6 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 7 of Set 6 | adwa
# Processing Record 8 of Set 6 | jijiga
# Processing Record 9 of Set 6 | soyo
# Processing Record 10 of Set 6 | la romana
# Processing Record 11 of Set 6 | sorland
# Processing Record 12 of Set 6 | champerico
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | havoysund
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | opalenica
# Processing Record 17 of Set 6 | marsabit
# Processing Record 18 of Set 6 | hyeres
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | coari
# Processing Record 21 of Set 6 | umm kaddadah
# Processing Record 22 of Set 6 | brae
# Processing Record 23 of Set 6 | mporokoso
# Processing Record 24 of Set 6 | ilka
# City not found. Skipping...
# Processing Record 25 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 6 | sibu
# Processing Record 27 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 6 | santa rosa de lima
# Processing Record 29 of Set 6 | mizan teferi
# Processing Record 30 of Set 6 | fortuna
# Processing Record 31 of Set 6 | lanigan
# Processing Record 32 of Set 6 | kuusamo
# Processing Record 33 of Set 6 | pacific grove
# Processing Record 34 of Set 6 | urengoy
# Processing Record 35 of Set 6 | tucuma
# Processing Record 36 of Set 6 | los llanos de aridane
# Processing Record 37 of Set 6 | loandjili
# Processing Record 38 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 39 of Set 6 | batticaloa
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | kanker
# Processing Record 42 of Set 6 | rawson
# Processing Record 43 of Set 6 | bafoulabe
# Processing Record 44 of Set 6 | torbay
# Processing Record 45 of Set 6 | chom bung
# City not found. Skipping...
# Processing Record 46 of Set 6 | batagay
# Processing Record 47 of Set 6 | maceio
# Processing Record 48 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | sakakah
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | fort nelson
# Processing Record 4 of Set 7 | warrnambool
# Processing Record 5 of Set 7 | doka
# Processing Record 6 of Set 7 | dibulla
# Processing Record 7 of Set 7 | marzuq
# Processing Record 8 of Set 7 | moron
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | whitehorse
# Processing Record 11 of Set 7 | dongying
# Processing Record 12 of Set 7 | paralimni
# Processing Record 13 of Set 7 | tessalit
# Processing Record 14 of Set 7 | ust-ilimsk
# Processing Record 15 of Set 7 | coquimbo
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | pisco
# Processing Record 18 of Set 7 | bandarbeyla
# Processing Record 19 of Set 7 | smithers
# Processing Record 20 of Set 7 | bathsheba
# Processing Record 21 of Set 7 | manhumirim
# Processing Record 22 of Set 7 | hervey bay
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | urbana
# Processing Record 25 of Set 7 | mangla
# Processing Record 26 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 7 | vestmanna
# Processing Record 28 of Set 7 | suharau
# Processing Record 29 of Set 7 | fasa
# Processing Record 30 of Set 7 | muroto
# Processing Record 31 of Set 7 | talcahuano
# Processing Record 32 of Set 7 | mutsu
# Processing Record 33 of Set 7 | narsaq
# Processing Record 34 of Set 7 | noratus
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | saint-louis
# Processing Record 37 of Set 7 | tura
# Processing Record 38 of Set 7 | vestmannaeyjar
# Processing Record 39 of Set 7 | kropotkin
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | cabo san lucas
# Processing Record 42 of Set 7 | soe
# Processing Record 43 of Set 7 | vardo
# Processing Record 44 of Set 7 | zaysan
# Processing Record 45 of Set 7 | rafaela
# Processing Record 46 of Set 7 | mahon
# Processing Record 47 of Set 7 | acajutla
# Processing Record 48 of Set 7 | nabire
# Processing Record 49 of Set 7 | toungoo
# City not found. Skipping...
# Processing Record 50 of Set 7 | arys
# Processing Record 1 of Set 8 | tukrah
# Processing Record 2 of Set 8 | bol
# Processing Record 3 of Set 8 | ransang
# Processing Record 4 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 8 | puerto del rosario
# Processing Record 6 of Set 8 | varkkallai
# Processing Record 7 of Set 8 | baruun-urt
# Processing Record 8 of Set 8 | morrope
# Processing Record 9 of Set 8 | yerbogachen
# Processing Record 10 of Set 8 | kysyl-syr
# Processing Record 11 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 8 | walvis bay
# Processing Record 13 of Set 8 | pevek
# Processing Record 14 of Set 8 | paciran
# Processing Record 15 of Set 8 | iwanai
# Processing Record 16 of Set 8 | lerwick
# Processing Record 17 of Set 8 | udachnyy
# Processing Record 18 of Set 8 | kinshasa
# Processing Record 19 of Set 8 | macherla
# Processing Record 20 of Set 8 | nyrob
# Processing Record 21 of Set 8 | fukue
# Processing Record 22 of Set 8 | olinda
# Processing Record 23 of Set 8 | osakarovka
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | muromtsevo
# Processing Record 26 of Set 8 | lompoc
# Processing Record 27 of Set 8 | nuuk
# Processing Record 28 of Set 8 | tazovskiy
# Processing Record 29 of Set 8 | kambove
# Processing Record 30 of Set 8 | pleshanovo
# Processing Record 31 of Set 8 | presidencia roque saenz pena
# Processing Record 32 of Set 8 | ulladulla
# Processing Record 33 of Set 8 | conde
# Processing Record 34 of Set 8 | axim
# Processing Record 35 of Set 8 | okha
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | basti
# Processing Record 38 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 8 | mandiana
# Processing Record 40 of Set 8 | cabedelo
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | alugan
# Processing Record 43 of Set 8 | rio das pedras
# Processing Record 44 of Set 8 | muli
# Processing Record 45 of Set 8 | staryy krym
# Processing Record 46 of Set 8 | constitucion
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 8 | corinto
# Processing Record 50 of Set 8 | houma
# Processing Record 1 of Set 9 | nishihara
# Processing Record 2 of Set 9 | usinsk
# Processing Record 3 of Set 9 | nioro
# Processing Record 4 of Set 9 | west wendover
# Processing Record 5 of Set 9 | ust-kuyga
# Processing Record 6 of Set 9 | kosonsoy
# Processing Record 7 of Set 9 | shelomi
# Processing Record 8 of Set 9 | chumikan
# Processing Record 9 of Set 9 | aklavik
# Processing Record 10 of Set 9 | imbituba
# Processing Record 11 of Set 9 | makung
# City not found. Skipping...
# Processing Record 12 of Set 9 | neryungri
# Processing Record 13 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 9 | port-cartier
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | vila
# Processing Record 17 of Set 9 | novo aripuana
# Processing Record 18 of Set 9 | saint-michel-des-saints
# Processing Record 19 of Set 9 | linkou
# Processing Record 20 of Set 9 | punta alta
# Processing Record 21 of Set 9 | ellisras
# Processing Record 22 of Set 9 | mareeba
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | kant
# Processing Record 25 of Set 9 | leskolovo
# Processing Record 26 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 9 | lakheri
# Processing Record 28 of Set 9 | chimbote
# Processing Record 29 of Set 9 | tuntum
# Processing Record 30 of Set 9 | yamaga
# Processing Record 31 of Set 9 | lavos
# Processing Record 32 of Set 9 | gayeri
# Processing Record 33 of Set 9 | kurchum
# Processing Record 34 of Set 9 | vicuna
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | sept-iles
# Processing Record 38 of Set 9 | the pas
# Processing Record 39 of Set 9 | come
# Processing Record 40 of Set 9 | longyearbyen
# Processing Record 41 of Set 9 | zyryanovsk
# Processing Record 42 of Set 9 | mlonggo
# Processing Record 43 of Set 9 | duz
# City not found. Skipping...
# Processing Record 44 of Set 9 | katobu
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | acapulco
# Processing Record 47 of Set 9 | namikupa
# Processing Record 48 of Set 9 | aksu
# Processing Record 49 of Set 9 | manzhouli
# Processing Record 50 of Set 9 | codo
# Processing Record 1 of Set 10 | tanshui
# City not found. Skipping...
# Processing Record 2 of Set 10 | tottenham
# Processing Record 3 of Set 10 | sarab
# Processing Record 4 of Set 10 | jacareacanga
# Processing Record 5 of Set 10 | lagos
# Processing Record 6 of Set 10 | tautira
# Processing Record 7 of Set 10 | kilindoni
# Processing Record 8 of Set 10 | sao miguel do araguaia
# Processing Record 9 of Set 10 | healdsburg
# Processing Record 10 of Set 10 | chara
# Processing Record 11 of Set 10 | anshun
# Processing Record 12 of Set 10 | moranbah
# Processing Record 13 of Set 10 | dunmore town
# Processing Record 14 of Set 10 | puerto escondido
# Processing Record 15 of Set 10 | kulhudhuffushi
# Processing Record 16 of Set 10 | general pico
# Processing Record 17 of Set 10 | oreanda
# City not found. Skipping...
# Processing Record 18 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 10 | lewistown
# Processing Record 20 of Set 10 | ahome
# Processing Record 21 of Set 10 | inverell
# Processing Record 22 of Set 10 | klamath falls
# Processing Record 23 of Set 10 | turayf
# Processing Record 24 of Set 10 | zhengjiatun
# Processing Record 25 of Set 10 | huarmey
# Processing Record 26 of Set 10 | harper
# Processing Record 27 of Set 10 | malartic
# Processing Record 28 of Set 10 | henties bay
# Processing Record 29 of Set 10 | matamoros
# Processing Record 30 of Set 10 | zalantun
# Processing Record 31 of Set 10 | abu samrah
# Processing Record 32 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 33 of Set 10 | sobolevo
# Processing Record 34 of Set 10 | dhidhdhoo
# Processing Record 35 of Set 10 | plettenberg bay
# Processing Record 36 of Set 10 | berdigestyakh
# Processing Record 37 of Set 10 | minna
# Processing Record 38 of Set 10 | wukari
# Processing Record 39 of Set 10 | pinerolo
# Processing Record 40 of Set 10 | atar
# Processing Record 41 of Set 10 | san-pedro
# Processing Record 42 of Set 10 | menongue
# Processing Record 43 of Set 10 | liepaja
# Processing Record 44 of Set 10 | bonavista
# Processing Record 45 of Set 10 | shahr-e babak
# Processing Record 46 of Set 10 | kloulklubed
# Processing Record 47 of Set 10 | gweta
# Processing Record 48 of Set 10 | sonqar
# City not found. Skipping...
# Processing Record 49 of Set 10 | amapa
# Processing Record 50 of Set 10 | rusape
# Processing Record 1 of Set 11 | sovetskiy
# Processing Record 2 of Set 11 | andenes
# Processing Record 3 of Set 11 | boa viagem
# Processing Record 4 of Set 11 | karonga
# Processing Record 5 of Set 11 | port macquarie
# Processing Record 6 of Set 11 | kalmunai
# Processing Record 7 of Set 11 | el reno
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | tiznit
# Processing Record 10 of Set 11 | nemuro
# Processing Record 11 of Set 11 | bara
# Processing Record 12 of Set 11 | caidian
# Processing Record 13 of Set 11 | tilichiki
# Processing Record 14 of Set 11 | kungurtug
# Processing Record 15 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 11 | griffith
# Processing Record 17 of Set 11 | karratha
# Processing Record 18 of Set 11 | agua dulce
# Processing Record 19 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 11 | capao bonito
# Processing Record 21 of Set 11 | pangnirtung
# Processing Record 22 of Set 11 | madera
# Processing Record 23 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 11 | girua
# Processing Record 25 of Set 11 | nador
# Processing Record 26 of Set 11 | castlegar
# Processing Record 27 of Set 11 | luoyang
# Processing Record 28 of Set 11 | shingu
# Processing Record 29 of Set 11 | sao felix do xingu
# Processing Record 30 of Set 11 | nenjiang
# Processing Record 31 of Set 11 | aransas pass
# Processing Record 32 of Set 11 | afgoye
# City not found. Skipping...
# Processing Record 33 of Set 11 | santa cruz
# Processing Record 34 of Set 11 | pandamatenga
# Processing Record 35 of Set 11 | sakaiminato
# Processing Record 36 of Set 11 | kaspiysk
# Processing Record 37 of Set 11 | baykit
# Processing Record 38 of Set 11 | roald
# Processing Record 39 of Set 11 | sola
# Processing Record 40 of Set 11 | caceres
# Processing Record 41 of Set 11 | gimli
# Processing Record 42 of Set 11 | mitu
# Processing Record 43 of Set 11 | shubarshi
# Processing Record 44 of Set 11 | rondonopolis
# Processing Record 45 of Set 11 | ust-tsilma
# Processing Record 46 of Set 11 | aswan
# Processing Record 47 of Set 11 | khandbari
# Processing Record 48 of Set 11 | matara
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | luziania
# Processing Record 1 of Set 12 | bahia honda
# Processing Record 2 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 12 | ballina
# Processing Record 4 of Set 12 | ahuimanu
# Processing Record 5 of Set 12 | kota bahru
# Processing Record 6 of Set 12 | hearst
# Processing Record 7 of Set 12 | zhigansk
# Processing Record 8 of Set 12 | yokadouma
# Processing Record 9 of Set 12 | george
# Processing Record 10 of Set 12 | zaranj
# Processing Record 11 of Set 12 | saldanha
# Processing Record 12 of Set 12 | omsukchan
# Processing Record 13 of Set 12 | alyangula
# Processing Record 14 of Set 12 | ahipara
# Processing Record 15 of Set 12 | kiruna
# Processing Record 16 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 12 | iringa
# Processing Record 18 of Set 12 | inirida
# Processing Record 19 of Set 12 | binga
# Processing Record 20 of Set 12 | maumere
# Processing Record 21 of Set 12 | dzerzhinskoye
# Processing Record 22 of Set 12 | raudeberg
# Processing Record 23 of Set 12 | dalvik
# Processing Record 24 of Set 12 | waipawa
# Processing Record 25 of Set 12 | skawina
# Processing Record 26 of Set 12 | mednogorsk
# Processing Record 27 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 12 | pedernales
# Processing Record 29 of Set 12 | svetlogorsk
# Processing Record 30 of Set 12 | komatipoort
# Processing Record 31 of Set 12 | smila
# Processing Record 32 of Set 12 | kousseri
# Processing Record 33 of Set 12 | ayorou
# Processing Record 34 of Set 12 | svetlyy
# Processing Record 35 of Set 12 | roebourne
# Processing Record 36 of Set 12 | nantucket
# Processing Record 37 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 12 | madang
# Processing Record 39 of Set 12 | ayni
# Processing Record 40 of Set 12 | matay
# Processing Record 41 of Set 12 | gonbad-e qabus
# Processing Record 42 of Set 12 | nizhniy kuranakh
# Processing Record 43 of Set 12 | amazar
# Processing Record 44 of Set 12 | half moon bay
# Processing Record 45 of Set 12 | tynda
# Processing Record 46 of Set 12 | jalu
# Processing Record 47 of Set 12 | lasa
# Processing Record 48 of Set 12 | longonjo
# Processing Record 49 of Set 12 | collie
# Processing Record 50 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 13 | oksfjord
# Processing Record 2 of Set 13 | abapo
# Processing Record 3 of Set 13 | kuna
# Processing Record 4 of Set 13 | palmer
# Processing Record 5 of Set 13 | sussex
# Processing Record 6 of Set 13 | buenavista
# Processing Record 7 of Set 13 | alvaraes
# Processing Record 8 of Set 13 | salalah
# Processing Record 9 of Set 13 | wielun
# Processing Record 10 of Set 13 | dickson
# Processing Record 11 of Set 13 | sulina
# Processing Record 12 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 13 | beyneu
# Processing Record 14 of Set 13 | lavrentiya
# Processing Record 15 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 13 | ca mau
# Processing Record 17 of Set 13 | progreso
# Processing Record 18 of Set 13 | riyadh
# Processing Record 19 of Set 13 | harrisburg
# Processing Record 20 of Set 13 | alekseyevsk
# Processing Record 21 of Set 13 | tocopilla
# Processing Record 22 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 13 | inhambane
# Processing Record 24 of Set 13 | bouna
# Processing Record 25 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 13 | nurota
# Processing Record 27 of Set 13 | vilhena
# Processing Record 28 of Set 13 | xocali
# Processing Record 29 of Set 13 | berezanka
# Processing Record 30 of Set 13 | linz
# Processing Record 31 of Set 13 | kiama
# Processing Record 32 of Set 13 | zhezkazgan
# Processing Record 33 of Set 13 | igarka
# Processing Record 34 of Set 13 | rundu
# Processing Record 35 of Set 13 | bowen
# Processing Record 36 of Set 13 | srednekolymsk
# Processing Record 37 of Set 13 | phalombe
# Processing Record 38 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 39 of Set 13 | khandyga
# Processing Record 40 of Set 13 | miranda
# Processing Record 41 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 13 | freeport
# Processing Record 43 of Set 13 | merauke
# Processing Record 44 of Set 13 | anito
# Processing Record 45 of Set 13 | simao
# Processing Record 46 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 13 | baker city
# Processing Record 48 of Set 13 | knysna
# Processing Record 49 of Set 13 | amqui
# Processing Record 50 of Set 13 | pasco
# Processing Record 1 of Set 14 | fukuma
# Processing Record 2 of Set 14 | margate
# Processing Record 3 of Set 14 | sigli
# Processing Record 4 of Set 14 | harnosand
# Processing Record 5 of Set 14 | belogorsk
# Processing Record 6 of Set 14 | pacasmayo
# Processing Record 7 of Set 14 | kadyy
# Processing Record 8 of Set 14 | mazara del vallo
# Processing Record 9 of Set 14 | muisne
# Processing Record 10 of Set 14 | kirkwall
# Processing Record 11 of Set 14 | dauriya
# Processing Record 12 of Set 14 | hwange
# Processing Record 13 of Set 14 | natchitoches
# Processing Record 14 of Set 14 | amarillo
# Processing Record 15 of Set 14 | saint-paul
# Processing Record 16 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 14 | lambare
# Processing Record 18 of Set 14 | puerto colombia
# Processing Record 19 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 14 | cabra
# Processing Record 21 of Set 14 | cantagallo
# Processing Record 22 of Set 14 | pandan
# Processing Record 23 of Set 14 | sungaipenuh
# Processing Record 24 of Set 14 | santa rosalia
# Processing Record 25 of Set 14 | novosergiyevka
# Processing Record 26 of Set 14 | cornelius
# Processing Record 27 of Set 14 | bela
# Processing Record 28 of Set 14 | chapais
# Processing Record 29 of Set 14 | belmonte
# Processing Record 30 of Set 14 | nanakuli
# Processing Record 31 of Set 14 | poltava
# Processing Record 32 of Set 14 | thunder bay
# Processing Record 33 of Set 14 | alice springs
# Processing Record 34 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 14 | unye
# City not found. Skipping...
# Processing Record 36 of Set 14 | ngaoundere
# Processing Record 37 of Set 14 | gat
# Processing Record 38 of Set 14 | derzhavinsk
# Processing Record 39 of Set 14 | san jose de rio tinto
# Processing Record 40 of Set 14 | nong kung si
# Processing Record 41 of Set 14 | iquitos
# Processing Record 42 of Set 14 | luangwa
# Processing Record 43 of Set 14 | beloha
# Processing Record 44 of Set 14 | sambava
# Processing Record 45 of Set 14 | itacoatiara
# Processing Record 46 of Set 14 | gamba
# Processing Record 47 of Set 14 | melito di porto salvo
# Processing Record 48 of Set 14 | jiwani
# Processing Record 49 of Set 14 | komsomolskiy
# Processing Record 50 of Set 14 | gold coast
# Processing Record 1 of Set 15 | saint-joseph
# Processing Record 2 of Set 15 | bairnsdale
# Processing Record 3 of Set 15 | oktyabrskiy
# Processing Record 4 of Set 15 | pochutla
# Processing Record 5 of Set 15 | vao
# Processing Record 6 of Set 15 | gravdal
# Processing Record 7 of Set 15 | quang ngai
# Processing Record 8 of Set 15 | atbasar
# Processing Record 9 of Set 15 | taltal
# Processing Record 10 of Set 15 | dunmore
# Processing Record 11 of Set 15 | salinopolis
# Processing Record 12 of Set 15 | mecca
# Processing Record 13 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 14 of Set 15 | veinticinco de diciembre
# Processing Record 15 of Set 15 | teguise
# Processing Record 16 of Set 15 | suez
# Processing Record 17 of Set 15 | lyaskelya
# Processing Record 18 of Set 15 | chiautla
# Processing Record 19 of Set 15 | mountain home
# Processing Record 20 of Set 15 | susangerd
# Processing Record 21 of Set 15 | marsa matruh
# Processing Record 22 of Set 15 | miles city
# Processing Record 23 of Set 15 | rio gallegos
# Processing Record 24 of Set 15 | kudahuvadhoo
# Processing Record 25 of Set 15 | kihei
# Processing Record 26 of Set 15 | shieli
# Processing Record 27 of Set 15 | jucurutu
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | mount gambier
# Processing Record 30 of Set 15 | southbridge
# Processing Record 31 of Set 15 | saint anthony
# Processing Record 32 of Set 15 | yecla
# Processing Record 33 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 15 | salta
# Processing Record 35 of Set 15 | teruel
# Processing Record 36 of Set 15 | kasongo
# Processing Record 37 of Set 15 | avera
# Processing Record 38 of Set 15 | zaraysk
# Processing Record 39 of Set 15 | sinnamary
# Processing Record 40 of Set 15 | batemans bay
# Processing Record 41 of Set 15 | havre-saint-pierre
# Processing Record 42 of Set 15 | gohpur
# Processing Record 43 of Set 15 | verin
# Processing Record 44 of Set 15 | westport
# Processing Record 45 of Set 15 | luwuk
# Processing Record 46 of Set 15 | itarema
# Processing Record 47 of Set 15 | rajanpur
# Processing Record 48 of Set 15 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred      ZA -33.5906   26.8910     62.19        80         100
# 1  Bambous Virieux      MU -20.3428   57.7575     79.05        73          40
# 2          Sibolga      ID   1.7427   98.7792     78.49        86          84
# 3           Atuona      PF  -9.8000 -139.0333     78.85        81          20
# 4          Rikitea      PF -23.1203 -134.9692     78.10        72          47
# 5          Colares      PT  38.7992   -9.4469     77.99        50           0
# 6         Kirakira      SB -10.4544  161.9205     79.25        84          77
# 7          Ushuaia      AR -54.8000  -68.3000     42.46        65          75
# 8         Olafsvik      IS  64.8945  -23.7142     44.13        97         100
# 9            Kapaa      US  22.0752 -159.3190     73.72        87          75
#
#    Wind Speed   Current Description
# 0        1.01       overcast clouds
# 1       12.66      scattered clouds
# 2        3.18  heavy intensity rain
# 3       18.10            few clouds
# 4       16.60            light rain
# 5       10.36             clear sky
# 6        5.19         broken clouds
# 7       18.41         broken clouds
# 8       12.48            light rain
# 9       14.97         broken clouds

# %%
# Create the output file (CSV).
output_data_file = '../Weather_Database/WeatherPy_database.csv'

# %%
#export city_data into a CSV
city_data_df.to_csv(output_data_file)
